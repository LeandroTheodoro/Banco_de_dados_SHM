# %% [markdown]
# <a href="https://colab.research.google.com/github/LeandroTheodoro/Banco_de_dados_SHM/blob/main/Dispersion_curves_franciscorotea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/franciscorotea/Lamb-Wave-Dispersion
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/franciscorotea/Lamb-Wave-Dispersion to /tmp/pip-req-build-doet5e5w
#   Running command git clone --filter=blob:none --quiet https://github.com/franciscorotea/Lamb-Wave-Dispersion /tmp/pip-req-build-doet5e5w
#   Resolved https://github.com/franciscorotea/Lamb-Wave-Dispersion to commit a4f735fa4a3f232c0d2fc07ad0ab8b861b647159
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install numpy
# !pip install scipy
# !pip install matplotlib==3.5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from lambwaves import Lamb

alum = Lamb(thickness=1, 
            nmodes_sym=5, 
            nmodes_antisym=5, 
            fd_max=3000, 
            vp_max=7000, 
            c_L=6420, 
            c_S=3040)
# Out:
# Calculating symmetric modes..
#
# 0/100 - 0.0 kHz × mm
# 1/100 - 30.3 kHz × mm
# 2/100 - 60.6 kHz × mm
# 3/100 - 90.9 kHz × mm
# 4/100 - 121.2 kHz × mm
# 5/100 - 151.5 kHz × mm
# 6/100 - 181.8 kHz × mm
# 7/100 - 212.1 kHz × mm
# 8/100 - 242.4 kHz × mm
# 9/100 - 272.7 kHz × mm
# 10/100 - 303.0 kHz × mm
# 11/100 - 333.3 kHz × mm
# 12/100 - 363.6 kHz × mm
# 13/100 - 393.9 kHz × mm
# 14/100 - 424.2 kHz × mm
# 15/100 - 454.5 kHz × mm
# 16/100 - 484.8 kHz × mm
# 17/100 - 515.2 kHz × mm
# 18/100 - 545.5 kHz × mm
# 19/100 - 575.8 kHz × mm
# 20/100 - 606.1 kHz × mm
# 21/100 - 636.4 kHz × mm
# 22/100 - 666.7 kHz × mm
# 23/100 - 697.0 kHz × mm
# 24/100 - 727.3 kHz × mm
# 25/100 - 757.6 kHz × mm
# 26/100 - 787.9 kHz × mm
# 27/100 - 818.2 kHz × mm
# 28/100 - 848.5 kHz × mm
# 29/100 - 878.8 kHz × mm
# 30/100 - 909.1 kHz × mm
# 31/100 - 939.4 kHz × mm
# 32/100 - 969.7 kHz × mm
# 33/100 - 1000.0 kHz × mm
# 34/100 - 1030.3 kHz × mm
# 35/100 - 1060.6 kHz × mm
# 36/100 - 1090.9 kHz × mm
# ...

# %%
alum.plot_phase_velocity()
# Out:
# (<Figure size 700x400 with 1 Axes>,
#  <AxesSubplot:xlabel='Frequency × thickness [KHz × mm]', ylabel='Phase Velocity [m/s]'>)

# %%
alum.plot_wave_number() # este termo sempre me causou dúvida. Olhando para o gráfico abaixo, parece que o wave number é o número de ondas compreendido no pacote de ondas (ou seja, o número de ondas contidas no grupo) para uma dada frequência de excitação
# Out:
# (<Figure size 700x400 with 1 Axes>,
#  <AxesSubplot:xlabel='Frequency × thickness [KHz × mm]', ylabel='Wave Number [1/m]'>)
